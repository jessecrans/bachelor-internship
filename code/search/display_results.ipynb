# %%
# import packages
import pandas as pd
from auxiliary.filter_functions import *
from auxiliary.search_algorithm import *
from results import *
from testing import *
from astroquery.vizier import Vizier
from astroquery.simbad import Simbad, SimbadClass
import os
import glob
from astropy.table import Table
import numpy as np
from astropy.io import fits
import time
import matplotlib.pyplot as plt
from astropy.stats import poisson_conf_interval
import scipy
import re

# %%
# plot multifig of light curve and long light curve

# parameters
date_range = [
    '',
    # '2015-01-01',
    # '2022-04-01',
    ''
]

window_size = 50
exclusions = [20]

# get the de
detections = get_candidates(window_size, date_range[0], date_range[1], exclusions)

# divide the detections into multiple dataframes
group_size = 6
detections = [detections.iloc[i:i + group_size] for i in range(0, len(detections), group_size)]

for number, detection_group in enumerate(detections):
    plot_light_curve_multifig(detection_group, f'multifig_50ks_test_{number}')
# Out:
#             Id Previous Detection  ObsId Exp. (ks)  \
# 1  XRTC 001204                      1882    $96.8$
# 2  XRTC 030120                      4396   $164.6$
# 3  XRTC 060530                      6792    $97.3$
# 4  XRTC 100819                     12301    $78.0$
# 5  XRTC 110501                     12317    $78.5$
#
#                                  Date         $T_{90}$ (ks)     RA (deg)  \
# 1  \makecell{2000-12-02/\\2000-12-04}   $70.0^{7.4}_{11.1}$   $91.94792$
# 2  \makecell{2003-01-18/\\2003-01-20}  $45.2^{44.4}_{20.4}$   $83.84385$
# 3  \makecell{2006-05-29/\\2006-05-30}   $90.5^{4.1}_{17.9}$  $221.89159$
# 4  \makecell{2010-08-18/\\2010-08-19}    $58.7^{3.0}_{8.6}$  $148.88870$
# 5  \makecell{2011-04-30/\\2011-05-01}    $76.6^{3.5}_{4.9}$  $191.86629$
#
#     Dec (deg)       Off. Ang.              Pos. Unc.     S/N
# 1  $-6.39343$  $1.0^{\prime}$  $0.18^{\prime\prime}$  $15.1$
# 2  $-5.33084$  $4.1^{\prime}$  $0.15^{\prime\prime}$  $44.9$
# 3   $9.33420$  $6.0^{\prime}$  $0.85^{\prime\prime}$   $9.7$
# 4  $68.96563$  $3.2^{\prime}$  $0.42^{\prime\prime}$   $7.1$
# 5  $-2.15688$  $0.6^{\prime}$  $0.12^{\prime\prime}$  $33.2$

# %%
# plot the light curves of the candidates with no matches

# parameters
date_range = [
    # '',
    # '2015-01-01',
    '2022-04-01',
    ''
]

window_size = 20
exclusions = []

# no_matches = get_no_match_fxts(window=20, from_date=date_range[0], to_date=date_range[1])
no_matches = get_new_detections(20, True)
no_matches = get_candidates(window_size, date_range[0], date_range[1], exclusions)

for i, fxt in no_matches.iterrows():
    # pass
    lc = gen_light_curve(
        fxt['ObsId'],
        float(fxt['RA']),
        float(fxt['DEC']),
        float(fxt['THETA']),
    )
    print(fxt['ObsId'])
    plot_light_curve(
        fxt['ObsId'],
        float(fxt['RA']),
        float(fxt['DEC']),
        float(fxt['THETA']),
    )
# Out:
# 27611
# 23580
# 25212
# 22475
# 29320
# 23377
# 26643
# 25452
# 12317
# 15720
# 15720
# 18901
# 23485
# 1047
# 1520
# 1520
# 805
# 16024
# 6859
# 10303
# 10326
# 11674
# 13956
# 17036
# 19515
# 1711
# 1712
# 1712
# 894
# 926
# 4970
# 5757
# 8500
# 13020
# 18297
# 2253
# 4396
# 20617
# 11029
# 11029
# 13733
# 16745
# 21676
# 4449
# 18454
# 344
# 6830
# 7801
# 10351
# 16046
# 3265
# 5353
# 5353
# 7191
# 5800
# 11744
# 13471
# 16449
# 17308

# %%
# get table of number of observations, analysed observations, detections and no match detections

date_range = [
    # '',
    '2015-01-01',
    '2022-04-01',
    # ''
]

candidate_numbers = get_candidate_numbers(
    from_date=date_range[0], to_date=date_range[1], window=50.0)

column_names = {
    'Before': 'Paper I',
    'In': 'Paper II',
    'After': 'New Data'
}
candidate_numbers = candidate_numbers.rename(columns=column_names)

print(dataframe_to_latex(candidate_numbers))
# candidate_numbers
# Out:
# \begin{table}[h]
#     \centering
#     \caption{}
#     \begin{tabular}{ccccc}
#         \headerrow & \headercell{Total} & \headercell{Paper I} & \headercell{Paper II} & \headercell{New Data} \\
#         \oddrow Observations & 9799 & 4992 & 3311 & 1496 \\
#         \evenrow Analysed & 973 & 716 & 251 & 6 \\
#         \oddrow Detections & 615 & 549 & 66 & 0 \\
#         \evenrow Candidates & 40 & 37 & 3 & 0 \\
#         \multicolumn{5}{p{0.5\linewidth}}{\textbf{Notes:} }
#     \end{tabular}
#     \label{tab:enter_label}
# \end{table}

# %%
# get the criteria table for a certain date range like in the papers

date_range = [
    '',
    '2015-01-01',
    # '2022-04-01',
    # ''
]

criteria_table = get_criteria_table(from_date=date_range[0], to_date=date_range[1], window=20)

print(dataframe_to_latex(criteria_table))
# criteria_table
# Out:
# \begin{table}[h]
#     \centering
#     \caption{}
#     \begin{tabular}{ccccc}
#         \headerrow & \headercell{Matched} & \headercell{Unique Matched} & \headercell{Removed} & \headercell{Remaining} \\
#         \oddrow Archival X-ray date & 778 & 65 & 778 & 272 \\
#         \evenrow Cross-match with stars/Gaia & 710 & 56 & 173 & 99 \\
#         \oddrow NED + SIMBAD + VizieR & 746 & 28 & 32 & 63 \\
#         \multicolumn{5}{p{0.5\linewidth}}{\textbf{Notes:} }
#     \end{tabular}
#     \label{tab:enter_label}
# \end{table}

# %%
# check if fxts from papers are found in new code
paper_I_fxts = [
    [803, 186.38125, 13.06607],
    [2025, 167.86792, 55.67253],
    [8490, 201.24329, -43.04060],
    [9546, 211.25113, 53.65706],
    [9548, 170.07296, 12.97189],
    [14904, 345.49250, 15.94871],
    [4062, 76.77817, -31.86980],
    [5885, 318.12646, -63.49914],
    [9841, 175.00504, -31.91743],
    [12264, 90.00450, -52.71501],
    [12884, 212.12063, -27.05784],
    [13454, 15.93558, -21.81272],
    [15113, 45.26725, -77.88095],
    [16454, 53.16158, -27.85940],
]

paper_II_fxts = [
    [16093, 233.73496, 23.46849],
    [16453, 53.07672, -27.87345],
    [18715, 40.82972, 32.32390],
    [19310, 36.71489, -1.08317],
    [20635, 356.26437, -42.64494],
    [21831, 207.34711, 26.58421 ],
    [23103, 50.47516, 41.24704],
    [24604, 207.23523, 26.66230],
]

# paper_I_fxts = pd.DataFrame(paper_I_fxts, columns=['ObsId', 'RA', 'DEC'])
# paper_II_fxts = pd.DataFrame(paper_II_fxts, columns=['ObsId', 'RA', 'DEC'])

analysed = pd.read_csv('output/analysed_w20.txt', header=0, sep=' ', dtype=str)

print('Paper I FXTs')
for fxt in paper_I_fxts:
    detections = get_detections(str(fxt[0]), fxt[1], fxt[2], True)
    if not detections.empty:
        print(detections[['ObsId', 'RA', 'DEC']].to_string(index=False, header=False))
    elif not analysed[analysed['ObsId'] == str(fxt[0])].empty:
        print(f'{fxt[0]} - not detected')
    else:
        print(f'{fxt[0]} - not analysed')
print('')
print('Paper II FXTs')
for fxt in paper_II_fxts:
    detections = get_detections(str(fxt[0]), fxt[1], fxt[2], True)
    if not detections.empty:
        print(detections[['ObsId', 'RA', 'DEC']].to_string(index=False, header=False))
    elif not analysed[analysed['ObsId'] == str(fxt[0])].empty:
        print(f'{fxt[0]} - not detected')
    else:
        print(f'{fxt[0]} - not analysed')
# Out:
# Paper I FXTs
# 803 186.381579 13.066452
# 2025 167.86794 55.672528
# 8490 201.24335 -43.040584
# 9546 211.251125 53.65706
# 9548 170.072881 12.971883
# 14904 345.492502 15.948704
# 4062 76.778177 -31.86982
# 5885 318.126599 -63.49898
# 9841 175.005028 -31.917419
# 12264 90.004429 -52.715044
# 12884 212.120467 -27.057995
# 13454 15.935694 -21.812707
# 15113 45.268361 -77.880922
# 16454 53.161632 -27.859487
#
# Paper II FXTs
# 16093 233.734807 23.468395
# 16453 53.076762 -27.873612
# 18715 40.829608 32.323772
# 19310 - not analysed
# 20635 356.264589 -42.644933
# 21831 207.347187 26.584447
# 23103 50.47529 41.246834
# 24604 - not detected

# %%
# get fxt table for certain date range

date_range = [
    # '',
    '2015-01-01',
    '2022-04-01',
    # ''
]

no_match = get_fxt_table(from_date=date_range[0], to_date=date_range[1])
no_match = no_match[no_match['ObsId'] != 2561]
# reset indices to integers starting from 1
no_match = no_match.reset_index(drop=True) # this starts from 0
no_match.index += 1
no_match = no_match.drop(columns=['Prev. Det.'])

no_match
# Out:
#                       Id  ObsId Exp. (ks)                                Date  \
# 1             XRT 140507  16093    $66.7$                          2014-05-07
# 2            XRTC 140105  16302    $39.2$                          2014-01-05
# 3   XRT 150322/CDF-S XT2  16453    $70.3$  \makecell{2015-03-21/\\2015-03-22}
# 4            XRTC 161209  17615    $26.3$  \makecell{2016-12-08/\\2016-12-09}
# 5            XRTC 161209  17615    $26.3$  \makecell{2016-12-08/\\2016-12-09}
# 6             XRT 151121  18715    $21.8$  \makecell{2015-11-20/\\2015-11-21}
# 7            XRTC 170115  18926    $79.0$  \makecell{2017-01-14/\\2017-01-15}
# 8            XRTC 171213  18927    $37.4$                          2017-12-13
# 9             XRT 170901  20635    $74.2$  \makecell{2017-08-31/\\2017-09-01}
# 10            XRT 191127  21831    $19.8$  \makecell{2019-11-26/\\2019-11-27}
# 11           XRTC 200413  22558    $19.8$  \makecell{2020-04-12/\\2020-04-13}
# 12            XRT 191223  23103    $16.4$                          2019-12-23
#
#                $T_{90}$     RA (deg)    Dec (deg)     Off. Ang.  \
# 1     $4.8^{3.5}_{5.5}$  $233.73481$   $23.46840$  $2.2\arcmin$
# 2    $34.2^{1.0}_{2.6}$  $209.00455$  $-32.58773$  $7.8\arcmin$
# 3    $10.5^{7.7}_{5.8}$   $53.07676$  $-27.87361$  $4.3\arcmin$
# 4    $24.0^{1.7}_{7.6}$  $207.62469$   $26.69989$  $2.0\arcmin$
# 5    $19.2^{3.6}_{7.3}$  $207.61486$   $26.74966$  $4.7\arcmin$
# 6   $17.9^{12.3}_{0.6}$   $40.82961$   $32.32377$  $8.6\arcmin$
# 7    $73.1^{2.8}_{3.0}$   $81.31800$    $1.60695$  $3.0\arcmin$
# 8     $6.1^{2.3}_{2.5}$   $83.87398$   $-4.99735$  $0.2\arcmin$
# 9     $4.2^{0.9}_{0.8}$  $356.26459$  $-42.64493$  $3.1\arcmin$
# 10   $0.5^{0.2}_{12.1}$  $207.34719$   $26.58445$  $5.9\arcmin$
# 11    $7.4^{0.8}_{6.9}$  $289.58998$   $49.60696$  $4.2\arcmin$
# 12    $3.7^{0.6}_{1.8}$   $50.47529$   $41.24683$  $3.5\arcmin$
#
#         Pos. Unc.     S/N
# 1   $0.33\arcsec$   $9.6$
# 2   $1.11\arcsec$  $12.5$
# 3   $0.24\arcsec$  $45.7$
# 4   $0.29\arcsec$   $6.5$
# 5   $0.82\arcsec$  $10.6$
# 6   $1.83\arcsec$   $9.0$
# 7   $0.12\arcsec$  $74.8$
# 8   $0.26\arcsec$  $11.9$
# 9   $0.14\arcsec$  $61.8$
# 10  $0.85\arcsec$  $11.7$
# 11  $0.30\arcsec$  $43.5$
# 12  $0.46\arcsec$  $10.7$

# %%
# get fxt dataframe for detections

date_range = [
    # '',
    # '2015-01-01',
    '2022-04-01',
    ''
]

detections = get_new_detections(50, True)
dataframe = get_fxt_dataframe_detections(detections)

dataframe.to_csv('tables/all_50ks.csv', index=True)
dataframe
# Out:
# \begin{table}[h]
#     \centering
#     \caption{}
#     \begin{tabular}{cccccccccccc}
#         \headerrow & \headercell{Id} & \headercell{Previous Detection} & \headercell{ObsId} & \headercell{Exp. (ks)} & \headercell{Date} & \headercell{T_90} & \headercell{RA (deg)} & \headercell{Dec (deg)} & \headercell{Off. Ang.} & \headercell{Pos. Unc.} & \headercell{S/N} \\
#         \multicolumn{12}{p{0.5\linewidth}}{\textbf{Notes:} }
#     \end{tabular}
#     \label{tab:enter_label}
# \end{table}

# %%
# get fxt table for new detections in 10 ks comapred to 20ks

new_detections = get_new_detections(10, True)
fxt_table = get_fxt_dataframe_detections(new_detections)
fxt_table = fxt_table.drop(columns=['Previous Detection'])

# print(dataframe_to_latex(fxt_table))
fxt_table
# Out:
#              Id  ObsId Exp. (ks)                     Date              T_90  \
# 1   XRTC 000222    344      47.4  2000-02-21 - 2000-02-22    43.4 +0.6 -0.5
# 2   XRTC 000209    805      40.8  2000-02-08 - 2000-02-09    13.3 +1.1 -1.2
# 3   XRTC 001021    894      39.4  2000-10-20 - 2000-10-21    35.8 +1.4 -1.3
# 4   XRTC 000611    926      44.2               2000-06-11    39.3 +3.6 -3.0
# 5   XRTC 001009   1047      32.2               2000-10-09    29.2 +2.0 -1.4
# 6   XRTC 000203   1520      23.7               2000-02-03    21.0 +1.6 -1.7
# 7   XRTC 000203   1520      23.7               2000-02-03    21.1 +1.6 -1.5
# 8   XRTC 000614   1711      27.1               2000-06-14    25.3 +0.9 -1.0
# 9   XRTC 000614   1712      27.4               2000-06-14    25.0 +1.0 -1.0
# 10  XRTC 000614   1712      27.4               2000-06-14    24.2 +1.0 -1.1
# 11  XRTC 020115   2253      47.4  2002-01-14 - 2002-01-15    41.9 +2.2 -3.5
# 12  XRTC 021002   3265      17.9               2002-10-02    16.2 +1.3 -0.8
# 13  XRTC 030120   4396     164.6  2003-01-18 - 2003-01-20  45.2 +20.4 -44.4
# 14  XRTC 030812   4449      18.2  2003-08-11 - 2003-08-12    15.8 +2.3 -1.0
# 15  XRTC 041023   4970      98.8  2004-10-22 - 2004-10-23    87.5 +2.0 -2.7
# 16  XRTC 040802   5353      36.6  2004-08-01 - 2004-08-02    32.7 +2.0 -1.8
# 17  XRTC 040802   5353      36.6  2004-08-01 - 2004-08-02    34.7 +3.0 -1.2
# 18  XRTC 050903   5757      59.0  2005-09-02 - 2005-09-03    53.9 +3.5 -3.9
# 19  XRTC 051023   5800      44.5  2005-10-22 - 2005-10-23    41.1 +1.8 -1.5
# 20  XRTC 060903   6830      94.4  2006-09-02 - 2006-09-03    86.8 +3.8 -3.4
# 21  XRTC 060514   6859      14.8               2006-05-14    12.2 +1.9 -1.1
# 22  XRTC 060519   7191      69.2               2006-05-19    63.9 +3.1 -4.1
# 23  XRTC 070910   7801      14.6               2007-09-10    12.9 +1.0 -1.1
# 24  XRTC 061230   8500      21.8               2006-12-30    15.0 +0.8 -1.2
# 25  XRTC 090108  10303      59.5               2009-01-08    55.0 +2.0 -3.0
# 26  XRTC 090323  10326      10.0               2009-03-23     8.8 +0.9 -0.5
# 27  XRTC 090815  10351      14.8               2009-08-15    12.9 +2.3 -0.8
# 28  XRTC 090826  11029      34.2               2009-08-26    31.7 +0.9 -0.7
# 29  XRTC 090826  11029      34.2               2009-08-26    31.2 +0.8 -0.7
# 30  XRTC 100320  11674      14.8               2010-03-20    13.3 +1.1 -1.1
# 31  XRTC 090903  11744      69.1               2009-09-03    63.7 +2.8 -2.5
# 32  XRTC 110501  12317      78.5  2011-04-30 - 2011-05-01    72.7 +4.0 -3.1
# 33  XRTC 100810  13020      41.5               2010-08-10    37.2 +3.0 -2.3
# 34  XRTC 120812  13471      55.2  2012-08-11 - 2012-08-12    50.6 +2.6 -2.6
# 35  XRTC 121114  13733      18.8               2012-11-14    15.7 +0.6 -0.5
# 36  XRTC 120210  13956      20.1               2012-02-10    17.7 +1.6 -1.6
# 37  XRTC 131208  15720      27.6               2013-12-08    25.8 +1.2 -0.7
# 38  XRTC 131208  15720      27.6               2013-12-08    24.7 +2.4 -1.5
# 39  XRTC 140607  16024      29.6               2014-06-07    26.6 +2.3 -1.7
# 40  XRTC 140925  16046      11.9               2014-09-25     9.8 +1.9 -0.5
# 41  XRTC 150928  16449      24.6               2015-09-28    22.2 +0.3 -0.3
# 42  XRTC 160610  16745      45.4  2016-06-09 - 2016-06-10    41.5 +3.9 -2.3
# 43  XRTC 151207  17036      12.9               2015-12-07    10.7 +2.0 -2.8
# 44  XRTC 150711  17308      44.8  2015-07-10 - 2015-07-11    40.2 +1.7 -1.9
# 45  XRTC 160328  18297      11.9               2016-03-28    10.0 +0.9 -0.4
# 46  XRTC 160629  18454      49.5               2016-06-29    45.1 +0.7 -0.9
# 47  XRTC 170404  18901      59.4               2017-04-04    53.7 +1.5 -2.8
# 48  XRTC 180114  19515      32.6  2018-01-13 - 2018-01-14    29.7 +2.5 -1.5
# 49  XRTC 190213  20617      23.8  2019-02-12 - 2019-02-13    21.9 +5.2 -1.9
# 50  XRTC 180825  21676      65.5  2018-08-24 - 2018-08-25    59.4 +3.3 -3.6
# 51  XRTC 210705  22475      22.4               2021-07-05    13.6 +5.8 -3.1
# 52  XRTC 210605  23377      28.6               2021-06-05    26.6 +1.0 -0.8
# 53  XRTC 210221  23485      32.2               2021-02-21    29.1 +1.7 -1.1
# 54  XRTC 211129  23580      29.7               2021-11-29    26.1 +1.8 -1.8
# 55  XRTC 230101  25212      13.1               2023-01-01    11.8 +1.2 -0.6
# 56  XRTC 221220  25452      12.8               2022-12-20     7.1 +1.6 -4.4
# 57  XRTC 221104  26643      18.8               2022-11-04    17.4 +1.4 -0.7
# 58  XRTC 221225  27611      19.8  2022-12-24 - 2022-12-25    17.4 +1.6 -1.7
# 59  XRTC 240316  29320      10.9               2024-03-16     5.3 +2.4 -1.0
#
#      RA (deg)  Dec (deg) Off. Ang. Pos. Unc.    S/N
# 1    40.66962   -0.01274       0.6      0.02  523.8
# 2   142.94319   55.19166      18.9      1.12   18.0
# 3   258.02855   64.14214       6.0      0.24   66.5
# 4   152.67783  -12.87157      13.2      1.34   20.3
# 5   255.86135   51.95720      12.7      1.17   31.5
# 6   154.84019   41.34584      15.4      2.11   18.7
# 7   154.71636   41.25359      14.5      1.91   17.6
# 8   187.12791    1.69688      24.4      3.42    6.9
# 9   187.27452    2.04868       0.4      0.00   72.8
# 10  187.27417    2.04826       0.4      0.06   70.2
# 11  187.20522   75.58803       9.7      0.68   41.2
# 12   29.95563   -8.83288       2.2      0.14   78.0
# 13   83.84385   -5.33084       4.1      0.15   44.9
# 14   22.53429   21.81805       4.7      0.40   35.7
# 15  139.50595  -11.76927      18.5      1.44    8.0
# 16  329.35219   -4.68083      12.6      1.54   17.7
# 17  329.41304   -4.69677      15.6      2.61    7.3
# 18  180.82716   57.80398       6.3      0.29   80.9
# 19   64.86444    2.55921       4.0      0.13  151.9
# 20   14.73732   26.95390       9.0      0.40   55.2
# 21  242.97912   52.46081       2.0      0.14   38.1
# 22   61.16424  -41.03927       5.7      0.20   83.5
# 23   24.92968  -10.50559      12.6      1.90   13.6
# 24  130.24038   32.61128      11.2      2.24    7.8
# 25  103.95847   54.41777      16.8      1.43   15.7
# 26  141.68290    2.55548       3.3      0.25   41.3
# 27  351.69291    9.89682      15.2      4.02    6.5
# 28  322.49172   12.16696       0.0      0.04  274.5
# 29  322.49227   12.16803       0.1      0.05  283.0
# 30  199.36469  -16.79776      11.9      1.13   40.0
# 31  355.81474  -55.38966       2.4      0.06  197.9
# 32  191.87038   -2.23492       4.5      0.12   97.6
# 33  239.06231   66.34653       3.2      0.19   64.1
# 34    3.67566  -49.88649       3.9      0.09  141.1
# 35  283.77740  -22.70123       0.3      0.04  284.7
# 36  133.35603   50.54639      10.3      2.41    7.7
# 37  189.30803  -41.03530      13.1      1.35   35.7
# 38  189.30326  -40.85130       2.2      0.14   38.4
# 39  204.24157  -29.85993       0.5      0.08   75.6
# 40   17.60692   31.74725       2.8      0.13   46.6
# 41   84.44676  -69.17207       6.8      0.08  377.8
# 42   64.37744  -62.78640       0.2      0.09   36.9
# 43  132.85745   39.59486       0.3      0.14   34.9
# 44   34.02208   -5.27619      20.0      2.10    9.3
# 45  186.58560  -49.20328       6.7      0.46   44.6
# 46  287.51061  -63.83472       2.0      0.03  975.9
# 47  182.01652  -38.96964       3.8      0.08  255.7
# 48  150.50757   45.31461      10.0      1.20   21.9
# 49    4.62894   44.02895       0.8      0.14   37.9
# 50  349.04590  -42.58517       0.1      0.09   99.0
# 51  110.91872   80.27623      11.2      2.59    6.6
# 52   45.46007  -16.59322       0.4      0.05  440.3
# 53  187.62640   41.64835       2.9      0.13   59.4
# 54  170.24664   39.17189       3.8      0.18   80.2
# 55  228.92389  -19.36898       6.0      0.51   41.5
# 56  333.81844   37.12188      11.5      2.60    9.8
# 57   50.04502    8.74877       0.2      0.13   56.6
# 58  184.73933   11.12729       0.6      0.07  212.8
# 59  169.58073    0.50314       6.3      1.06    5.9

# %%
# get fxt table for new detections in 30 ks compared to 20 ks

new_detections = get_new_detections(30, True)
fxt_table = get_fxt_dataframe_detections(new_detections)
fxt_table = fxt_table.drop(columns=['Previous Detection'])

# print(dataframe_to_latex(fxt_table))
fxt_table
# Out:
#              Id  ObsId Exp. (ks)                     Date              T_90  \
# 1   XRTC 000322    829      47.0  2000-03-21 - 2000-03-22   38.0 +15.5 -7.4
# 2   XRTC 001204   1882      96.8  2000-12-02 - 2000-12-04   77.1 +14.5 -2.5
# 3   XRTC 020521   2949      34.2               2002-05-21    27.3 +8.1 -9.9
# 4   XRTC 030706   3951      89.1  2003-07-05 - 2003-07-06   74.1 +17.8 -5.5
# 5   XRTC 030120   4396     164.6  2003-01-18 - 2003-01-20  45.2 +20.4 -44.4
# 6   XRTC 040913   5023      67.2  2004-09-12 - 2004-09-13    52.6 +2.4 -7.4
# 7   XRTC 091103  10453      34.7               2009-11-03    29.5 +5.7 -4.4
# 8   XRTC 100819  12301      78.0  2010-08-18 - 2010-08-19    58.7 +8.6 -3.0
# 9   XRTC 110501  12317      78.5  2011-04-30 - 2011-05-01    76.6 +4.9 -3.5
# 10  XRTC 110811  13478      79.4  2011-08-10 - 2011-08-11    73.1 +3.3 -2.5
#
#      RA (deg)  Dec (deg) Off. Ang. Pos. Unc.   S/N
# 1    69.30900   29.71758       4.1      0.35  10.7
# 2    91.94128   -6.40028       1.6      0.16  27.5
# 3   200.55265  -36.74750       7.2      1.73   7.0
# 4   170.32906   53.06506       4.8      0.67  13.9
# 5    83.84385   -5.33084       4.1      0.15  44.9
# 6   161.51616   59.11211       6.0      0.81  11.1
# 7   216.61302   33.75577       6.0      0.72  10.3
# 8   148.88870   68.96563       3.2      0.42   7.1
# 9   191.86629   -2.15688       0.6      0.12  33.2
# 10  311.08752  -50.59842       7.0      0.48  44.1

# %%
# get fxt table for new detections in 50 compared to 20 ks

new_detections = get_new_detections(50, True)
fxt_table = get_fxt_dataframe_detections(new_detections)
fxt_table = fxt_table.drop(columns=['Previous Detection'])

# print(dataframe_to_latex(fxt_table))

fxt_table
# Out:
#             Id  ObsId Exp. (ks)                     Date              T_90  \
# 1  XRTC 001204   1882      96.8  2000-12-02 - 2000-12-04   70.0 +11.1 -7.4
# 2  XRTC 030120   4396     164.6  2003-01-18 - 2003-01-20  45.2 +20.4 -44.4
# 3  XRTC 060530   6792      97.3  2006-05-29 - 2006-05-30   90.5 +17.9 -4.1
# 4  XRTC 100819  12301      78.0  2010-08-18 - 2010-08-19    58.7 +8.6 -3.0
# 5  XRTC 110501  12317      78.5  2011-04-30 - 2011-05-01    76.6 +4.9 -3.5
#
#     RA (deg) Dec (deg) Off. Ang. Pos. Unc.   S/N
# 1   91.94792  -6.39343       1.0      0.18  15.1
# 2   83.84385  -5.33084       4.1      0.15  44.9
# 3  221.89159   9.33420       6.0      0.85   9.7
# 4  148.88870  68.96563       3.2      0.42   7.1
# 5  191.86629  -2.15688       0.6      0.12  33.2
